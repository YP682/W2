# %%
import serial
import time
import csv
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

# Establish serial connection (adjust 'COM5' to your Arduino's port)
try:
    ser = serial.Serial('COM5', 9600)  # Replace 'COM5' with your actual port
    print("Serial port opened successfully.")
except Exception as e:
    print(f"Error opening serial port: {e}")
    ser = None

if ser:
    # Open CSV file to write data
    with open('accelerometer_data.csv', mode='a', newline='') as file:
        writer = csv.writer(file)
        
        # Continuously read data from Arduino
        try:
            print("Starting data collection...")
            while True:
                if ser.in_waiting > 0:
                    line = ser.readline().decode('utf-8').strip()
                    print(f"Data received: {line}")  # Debug print
                    timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
                    data = line.split(', ')
                    if len(data) == 3:  # Ensure correct data format
                        writer.writerow([timestamp] + data)
                    else:
                        print(f"Unexpected data format: {line}")
                    time.sleep(1)  # Adjust sampling rate if needed
                else:
                    print("Waiting for data...")  # Debug print
                    time.sleep(1)
        except KeyboardInterrupt:
            print("Data collection stopped.")
        finally:
            ser.close()
            print("Serial port closed.")

# Read the CSV file
data = pd.read_csv('accelerometer_data.csv', header=None, names=['timestamp', 'x', 'y', 'z'])

# Convert the timestamp column to a readable datetime format
data['timestamp'] = pd.to_datetime(data['timestamp'].astype(str), format='%Y%m%d%H%M%S')

# Print the first few rows to check the conversion
print(data.head())

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(data['timestamp'], data['x'], label='X-axis')
plt.plot(data['timestamp'], data['y'], label='Y-axis')
plt.plot(data['timestamp'], data['z'], label='Z-axis')
plt.xlabel('Time')
plt.ylabel('Acceleration (g)')
plt.title('Accelerometer Data')
plt.legend()
plt.show()
# Out:
# Serial port opened successfully.
# Starting data collection...
# Waiting for data...
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.04, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.04, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.04, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.20, -0.11, 1.01
# Data received: -0.00, -0.04, 1.01
# Data received: -0.01, -0.05, 1.01
# Data received: 0.01, -0.02, 1.02
# Data received: -0.11, -0.04, 1.01
# Data received: -0.01, -0.02, 1.01
# Data received: -0.02, -0.03, 1.01
# Data received: 0.01, -0.03, 1.01
# Data received: -0.05, -0.04, 1.01
# Data received: -0.04, -0.02, 1.01
# Data received: -0.02, -0.04, 1.01
# Data received: 0.02, -0.03, 1.01
# Data received: 0.05, -0.05, 1.01
# Data received: 0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.02, -0.04, 1.01
# Data received: 0.10, -0.04, 1.01
# Data received: -0.04, -0.02, 1.01
# Data received: -0.02, -0.03, 1.01
# Data received: 0.02, -0.03, 1.01
# Data received: 0.04, -0.03, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: 0.01, -0.01, 1.01
# Data received: 0.08, -0.04, 1.01
# Data received: -0.04, -0.01, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.02, -0.05, 1.01
# Data received: -0.00, -0.02, 1.01
# Data received: -0.06, -0.04, 1.01
# Data received: -0.10, 0.04, 1.01
# Data received: -0.06, -0.03, 0.97
# Data received: -0.17, -0.01, 1.03
# Data received: -0.12, 0.03, 1.00
# Data received: -0.08, -0.08, 0.95
# Data received: -0.19, 0.42, 1.10
# Data received: 0.08, -0.04, 1.00
# Data received: 0.14, 0.03, 1.00
# Data received: 0.10, -0.14, 0.99
# Data received: 0.09, -0.13, 0.97
# Data received: 0.07, -0.09, 1.03
# Data received: 0.09, -0.19, 1.00
# Data received: 0.28, 0.04, 0.89
# Data received: 0.02, -0.06, 0.94
# Data received: 0.24, -0.06, 1.13
# Data received: 0.02, 0.02, 1.02
# Data received: 0.12, -0.02, 0.99
# Data received: 0.09, 0.03, 1.16
# Data received: 0.17, -0.03, 1.16
# Data received: 0.13, -0.11, 1.00
# Data received: -0.01, -0.18, 1.24
# Data received: 0.00, 0.03, 1.05
# Data received: 0.07, 0.00, 1.01
# Data received: 0.17, -0.14, 0.99
# Data received: 0.04, 0.10, 0.87
# Data received: 0.10, 0.07, 1.13
# Data received: 0.01, -0.08, 1.09
# Data received: 0.06, 0.05, 0.95
# Data received: 0.03, -0.08, 1.13
# Data received: 0.07, 0.04, 0.97
# Data received: 0.01, 0.10, 1.00
# Data received: 0.00, -0.08, 1.06
# Data received: -0.01, 0.02, 1.21
# Data received: 0.16, -0.03, 0.94
# Data received: 0.01, -0.03, 1.02
# Data received: -0.02, -0.03, 1.07
# Data received: 0.07, -0.02, 0.94
# Data received: 0.07, 0.01, 0.93
# Data received: 0.00, -0.10, 1.02
# Data received: 0.03, 0.08, 0.87
# Data received: 0.09, 0.01, 1.06
# Data received: 0.07, -0.03, 0.93
# Data received: 0.01, -0.07, 1.01
# Data received: 0.03, -0.08, 1.01
# Data received: 0.13, -0.01, 0.94
# Data received: 0.12, 0.06, 0.98
# Data received: 0.11, 0.01, 1.06
# Data received: 0.07, -0.17, 1.04
# Data received: 0.27, -0.11, 1.08
# Data received: -0.01, -0.00, 1.00
# Data received: 0.16, -0.11, 1.11
# Data received: 0.35, 0.21, 0.83
# Data received: 0.01, -0.03, 0.99
# Data received: 0.29, 0.11, 1.14
# Data received: 0.07, -0.17, 0.93
# Data received: 0.12, -0.07, 1.05
# Data received: 0.06, -0.06, 1.15
# Data received: -0.11, -0.08, 1.03
# Data received: 0.17, -0.12, 1.08
# Data received: 0.04, -0.07, 1.09
# Data received: 0.22, -0.08, 0.96
# Data received: 0.19, -0.11, 0.99
# Data received: 0.07, -0.15, 0.82
# Data received: 0.16, -0.20, 0.91
# Data received: -0.12, -0.14, 1.07
# Data received: -0.01, -0.23, 1.02
# Data received: 0.15, -0.08, 0.97
# Data received: 0.28, 0.04, 0.99
# Data received: 0.08, -0.16, 1.19
# Data received: -0.03, -0.21, 1.00
# Data received: -0.05, -0.22, 0.91
# Data received: 0.16, 0.03, 0.87
# Data received: 0.01, -0.03, 0.84
# Data received: 0.08, -0.09, 0.96
# Data received: -0.37, -0.31, 1.06
# Data received: 0.08, 0.21, 0.73
# Data received: -0.15, -0.32, 0.91
# Data received: 0.12, -0.31, 1.22
# Data received: 0.17, -0.03, 1.06
# Data received: 0.13, 0.11, 0.99
# Data received: 0.10, -0.09, 1.01
# Data received: -0.04, -0.10, 0.92
# Data received: 0.21, 0.05, 1.08
# Data received: 0.21, -0.09, 0.97
# Data received: 0.02, -0.01, 1.04
# Data received: 0.02, -0.05, 1.00
# Data received: 0.24, -0.19, 1.00
# Data received: 0.06, -0.05, 0.92
# Data received: 0.10, -0.07, 0.99
# Data received: 0.17, 0.02, 0.98
# Data received: 0.10, -0.06, 0.95
# Data received: 0.13, -0.23, 1.01
# Data received: 0.09, 0.10, 1.12
# Data received: 0.12, 0.00, 1.00
# Data received: 0.28, -0.24, 0.78
# Data received: 0.12, -0.09, 0.94
# Data received: 0.07, -0.12, 0.95
# Data received: 0.19, -0.16, 0.75
# Data received: 0.10, -0.22, 1.11
# Data received: 0.17, -0.07, 1.04
# Data received: 0.03, -0.04, 0.98
# Data received: 0.14, -0.16, 1.01
# Data received: 0.23, -0.04, 0.94
# Data received: -0.04, -0.10, 1.03
# Data received: 0.22, -0.10, 1.03
# Data received: 0.17, -0.14, 0.83
# Data received: 0.05, -0.03, 1.10
# Data received: 0.15, -0.16, 1.04
# Data received: 0.06, -0.03, 1.02
# Data received: 0.10, -0.18, 1.06
# Data received: 0.18, -0.17, 1.10
# Data received: -0.08, -0.13, 0.92
# Data received: 0.10, -0.11, 1.12
# Data received: 0.15, -0.14, 1.07
# Data received: 0.23, -0.01, 1.04
# Data received: -0.07, -0.13, 1.21
# Data received: 0.02, 0.23, 1.10
# Data received: 0.23, 0.26, 1.15
# Data received: -0.13, 0.17, 0.98
# Data received: 0.13, 0.20, 1.03
# Data received: 0.04, 0.16, 1.03
# Data received: -0.04, -0.01, 0.95
# Data received: 0.02, 0.01, 1.11
# Data received: -0.09, 0.05, 0.97
# Data received: 0.13, 0.02, 1.01
# Data received: 0.11, -0.02, 0.97
# Data received: -0.05, -0.10, 0.95
# Data received: -0.02, -0.07, 1.04
# Data received: 0.04, -0.06, 0.90
# Data received: 0.03, -0.18, 1.09
# Data received: 0.13, -0.00, 0.97
# Data received: -0.03, -0.04, 0.93
# Data received: 0.17, 0.01, 1.11
# Data received: -0.05, 0.01, 1.06
# Data received: 0.13, -0.05, 0.92
# Data received: 0.13, 0.05, 0.93
# Data received: 0.08, 0.06, 1.01
# Data received: 0.15, -0.07, 1.04
# Data received: -0.02, 0.08, 1.09
# Data received: 0.11, 0.06, 0.99
# Data received: 0.17, -0.01, 0.84
# Data received: 0.13, 0.15, 0.94
# Data received: 0.09, -0.12, 0.96
# Data received: -0.06, 0.23, 1.08
# Data received: 0.17, 0.02, 1.00
# Data received: 0.03, -0.22, 1.10
# Data received: 0.14, 0.00, 0.90
# Data received: 0.17, -0.07, 0.89
# Data received: 0.13, -0.01, 0.97
# Data received: 0.06, 0.08, 1.07
# Data received: 0.03, 0.09, 1.11
# Data received: 0.17, 0.10, 0.93
# Data received: 0.37, 0.12, 0.83
# Data received: 0.03, 0.13, 1.08
# Data received: 0.17, 0.08, 0.96
# Data received: 0.04, 0.07, 1.06
# Data received: -0.04, -0.03, 1.03
# Data received: 0.07, 0.10, 1.20
# Data received: -0.10, -0.04, 1.14
# Data received: 0.26, -0.11, 1.04
# Data received: -0.06, -0.08, 0.93
# Data received: 0.12, -0.19, 0.94
# Data received: 0.06, -0.12, 0.76
# Data received: -0.09, -0.09, 1.25
# Data received: 0.11, 0.13, 0.97
# Data received: 0.02, -0.01, 1.01
# Data received: 0.03, 0.02, 1.09
# Data received: 0.06, -0.05, 1.08
# Data received: -0.11, 0.01, 1.15
# Data received: -0.03, -0.13, 1.11
# Data received: 0.12, 0.02, 0.97
# Data received: 0.04, 0.01, 0.95
# Data received: 0.01, -0.10, 1.06
# Data received: 0.00, -0.13, 0.87
# Data received: 0.03, -0.16, 0.96
# Data received: 0.15, -0.01, 1.05
# Data received: -0.05, 0.05, 1.17
# Data received: 0.02, -0.04, 1.02
# Data received: 0.14, -0.07, 1.00
# Data received: -0.04, 0.00, 1.00
# Data received: 0.14, -0.25, 1.24
# Data received: -0.11, -0.05, 0.91
# Data received: 0.10, -0.27, 0.95
# Data received: 0.13, -0.05, 0.87
# Data received: 0.03, -0.08, 0.99
# Data received: -0.03, -0.11, 1.01
# Data received: 0.01, -0.09, 0.97
# Data received: -0.07, -0.09, 0.90
# Data received: -0.05, -0.07, 1.09
# Data received: 0.03, -0.26, 0.94
# Data received: 0.12, -0.05, 0.91
# Data received: -0.01, -0.02, 0.94
# Data received: 0.04, -0.21, 1.03
# Data received: 0.20, -0.13, 0.77
# Data received: -0.03, -0.11, 0.98
# Data received: -0.00, -0.04, 1.01
# Data received: -0.02, -0.07, 1.00
# Data received: -0.18, -0.11, 1.07
# Data received: 0.01, -0.00, 1.06
# Data received: 0.05, 0.07, 1.04
# Data received: -0.21, -0.07, 1.13
# Data received: 0.10, -0.04, 1.01
# Data received: -0.03, -0.13, 1.12
# Data received: -0.07, -0.09, 1.07
# Data received: -0.17, -0.25, 0.98
# Data received: -0.15, -0.16, 1.02
# Data received: -0.12, -0.22, 1.06
# Data received: 0.20, 0.03, 1.08
# Data received: 0.08, 0.06, 1.11
# Data received: 0.07, -0.08, 1.00
# Data received: 0.05, -0.22, 1.05
# Data received: 0.09, 0.06, 1.01
# Data received: 0.10, -0.02, 1.05
# Data received: 0.09, 0.01, 1.01
# Data received: 0.14, 0.08, 0.97
# Data received: 0.16, -0.07, 1.01
# Data received: 0.13, 0.01, 0.96
# Data received: 0.16, 0.12, 1.09
# Data received: 0.19, -0.07, 0.97
# Data received: 0.15, 0.07, 1.00
# Data received: 0.16, 0.16, 0.96
# Data received: 0.24, -0.04, 0.90
# Data received: 0.22, 0.02, 0.98
# Data received: 0.20, -0.07, 0.97
# Data received: 0.22, -0.05, 0.94
# Data received: 0.27, 0.01, 0.91
# Data received: 0.27, -0.13, 0.95
# Data received: 0.23, -0.03, 0.89
# Data received: 0.19, 0.18, 0.94
# Data received: 0.21, -0.04, 0.94
# Data received: 0.17, 0.15, 0.98
# Data received: 0.15, 0.15, 0.97
# Data received: 0.20, 0.03, 0.92
# Data received: 0.19, 0.21, 0.96
# Data received: 0.18, 0.16, 1.01
# Data received: 0.21, 0.07, 1.08
# Data received: 0.23, 0.27, 1.10
# Data received: 0.22, 0.12, 0.99
# Data received: 0.23, 0.11, 0.98
# Data received: 0.27, 0.27, 0.88
# Data received: 0.26, 0.11, 0.96
# Data received: 0.20, 0.17, 1.00
# Data received: 0.23, 0.30, 0.99
# Data received: 0.22, 0.06, 0.95
# Data received: 0.22, 0.29, 0.94
# Data received: 0.21, 0.18, 0.95
# Data received: 0.23, 0.09, 0.94
# Data received: 0.26, 0.31, 1.05
# Data received: 0.27, 0.12, 1.06
# Data received: 0.24, 0.24, 0.95
# Data received: 0.26, 0.23, 0.97
# Data received: 0.29, 0.09, 0.95
# Data received: 0.19, 0.29, 0.83
# Data received: 0.24, 0.09, 1.01
# Data received: 0.24, 0.32, 0.95
# Data received: 0.23, 0.16, 0.97
# Data received: 0.26, 0.15, 1.06
# Data received: 0.26, 0.25, 0.95
# Data received: 0.26, 0.13, 0.96
# Data received: 0.24, 0.23, 0.95
# Data received: 0.23, 0.21, 0.96
# Data received: 0.25, 0.10, 1.04
# Data received: 0.24, 0.30, 0.95
# Data received: 0.24, 0.10, 0.95
# Data received: 0.23, 0.19, 0.99
# Data received: 0.25, 0.30, 0.88
# Data received: 0.24, 0.14, 0.90
# Data received: 0.24, 0.31, 0.94
# Data received: 0.22, 0.25, 1.00
# Data received: 0.22, 0.16, 0.98
# Data received: 0.24, 0.36, 1.04
# Data received: 0.25, 0.14, 0.98
# Data received: 0.24, 0.36, 0.97
# Data received: 0.22, 0.15, 1.00
# Data received: 0.20, 0.23, 0.96
# Data received: 0.08, 0.30, 0.82
# Data received: 0.26, 0.10, 1.08
# Data received: 0.30, 0.30, 1.00
# Data received: 0.32, 0.06, 0.97
# Data received: 0.30, 0.25, 0.92
# Data received: 0.30, 0.16, 0.96
# Data received: 0.27, 0.14, 0.96
# Data received: 0.31, 0.26, 0.87
# Data received: 0.30, 0.07, 0.93
# Data received: 0.31, 0.29, 0.92
# Data received: 0.29, 0.10, 0.95
# Data received: 0.28, 0.18, 0.94
# Data received: 0.30, 0.27, 0.88
# Data received: 0.28, 0.13, 0.95
# Data received: 0.30, 0.34, 0.92
# Data received: 0.29, 0.15, 0.96
# Data received: 0.28, 0.18, 0.95
# Data received: -0.43, -0.07, 0.88
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.04, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.00, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: 0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.04, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.02
# Data received: -0.00, -0.03, 1.01
# Data received: 0.00, -0.03, 1.01
# Data received: -0.00, -0.03, 1.01
# Data received: 0.35, -0.44, 1.01
# Data received: -0.40, 0.64, 0.87
# Data received: -0.04, 0.86, 0.50
# Data received: 0.10, 0.91, 0.41
# Data received: 0.05, 0.93, 0.35
# Data received: 0.28, 1.04, 0.34
# Data received: 0.62, 0.66, 0.27
# Data received: 0.34, 0.85, 0.31
# Data received: 0.22, 0.99, 0.25
# Data received: 0.01, 0.98, 0.26
# Data received: 0.38, 0.92, 0.37
# Data received: 0.28, 1.02, 0.41
# Data received: 0.14, 0.83, 0.27
# Data received: -0.02, 0.98, 0.19
# Data received: 0.03, 0.89, 0.45
# Data received: 0.03, 0.93, 0.47
# Data received: 0.17, 0.86, 0.25
# Data received: 0.14, 1.08, 0.39
# Data received: -0.05, 0.93, 0.32
# Data received: 0.57, 0.87, 0.34
# Data received: 0.15, 0.88, 0.42
# Data received: 0.21, 0.92, 0.35
# Data received: 0.15, 0.89, 0.19
# Data received: 0.02, 0.88, 0.48
# Data received: 0.04, 0.88, 0.32
# Data received: 0.16, 0.85, 0.25
# Data received: 0.07, 0.93, 0.32
# Data received: 0.24, 0.93, 0.34
# Data received: 0.02, 0.99, 0.30
# Data received: 0.12, 0.90, 0.30
# Data received: 0.25, 0.87, 0.36
# Data received: 0.06, 0.97, 0.30
# Data received: 0.13, 0.96, 0.39
# Data received: 0.23, 1.03, 0.31
# Data received: 0.28, 1.02, 0.09
# Data received: 0.11, 1.03, 0.34
# Data received: -0.03, 0.96, 0.22
# Data received: 0.06, 0.95, 0.44
# Data received: 0.20, 0.80, 0.34
# Data received: 0.18, 0.91, 0.26
# Data received: 0.25, 1.00, 0.39
# Data received: -0.08, 0.94, 0.31
# Data received: 0.01, 0.94, 0.35
# Data received: 0.21, 0.92, 0.29
# Data received: 0.18, 1.10, 0.33
# Data received: -0.05, 0.92, 0.33
# Data received: 0.11, 0.79, 0.45
# Data received: 0.01, 0.96, 0.30
# Data received: -0.06, 0.99, 0.25
# Data received: 0.11, 0.99, 0.18
# Data received: 0.41, 0.92, -0.06
# Data received: 0.24, 0.96, 0.34
# Data received: 0.11, 0.90, 0.43
# Data received: 0.13, 0.94, 0.10
# Data received: 0.28, 0.92, 0.33
# Data received: 0.05, 1.05, 0.50
# Data received: -0.02, 0.88, 0.43
# Data received: 0.26, 1.06, 0.20
# Data received: 0.14, 0.99, 0.30
# Data received: -0.03, 1.05, 0.20
# Data received: -0.10, 0.86, 0.34
# Data received: 0.24, 0.93, 0.23
# Data received: 0.11, 0.93, 0.32
# Data received: -0.11, 0.99, 0.36
# Data received: -0.17, 0.93, 0.24
# Data received: 0.38, 0.95, 0.01
# Data received: 0.11, 0.92, 0.29
# Data received: -0.15, 0.84, 0.34
# Data received: 0.11, 0.88, 0.44
# Data received: 0.06, 1.07, 0.19
# Data received: 0.28, 0.97, 0.33
# Data received: 0.03, 0.95, 0.31
# Data received: -0.05, 1.12, 0.08
# Data received: -0.23, 1.07, 0.39
# Data received: -0.32, 0.75, 0.53
# Data received: -0.23, 0.78, 0.32
# Data received: -0.31, 0.90, 0.57
# Data received: -0.25, 0.80, 0.55
# Data received: -0.19, 0.78, 0.51
# Data received: -0.24, 0.80, 0.60
# Data received: -0.26, 0.91, 0.49
# Data received: -0.13, 1.12, 0.19
# Data received: 0.04, 1.03, 0.19
# Data received: 0.04, 1.00, 0.01
# Data received: 0.04, 0.99, 0.29
# Data received: 0.17, 0.78, 0.37
# Data received: 0.19, 0.93, 0.29
# Data received: -0.05, 1.05, 0.20
# Data received: 0.06, 0.91, 0.32
# Data received: 0.13, 1.00, 0.15
# Data received: 0.02, 0.84, 0.23
# Data received: 0.15, 1.01, 0.30
# Data received: 0.15, 1.09, 0.16
# Data received: 0.19, 0.96, 0.21
# Data received: 0.05, 0.93, 0.31
# Data received: 0.07, 0.96, 0.23
# Data received: -0.02, 1.11, 0.33
# Data received: 0.28, 0.86, 0.20
# Data received: 0.09, 1.14, 0.31
# Data received: -0.11, 1.09, 0.31
# Data received: -0.15, 0.94, 0.27
# Data received: -0.10, 0.88, 0.15
# Data received: 0.21, 0.93, 0.29
# Data received: -0.07, 1.02, 0.11
# Data received: 0.00, 0.98, 0.22
# Data received: -0.05, 0.99, 0.37
# Data received: 0.02, 1.12, 0.15
# Data received: 0.14, 0.97, 0.29
# Data received: -0.25, 0.92, 0.30
# Data received: -0.12, 0.99, 0.19
# Data received: -0.16, 0.81, 0.27
# Data received: 0.14, 0.90, 0.29
# Data received: 0.12, 0.83, 0.32
# Data received: 0.36, 0.93, 0.23
# Data received: 0.15, 0.89, 0.20
# Data received: 0.14, 0.90, 0.05
# Data received: 0.17, 0.86, 0.38
# Data received: 0.00, 1.04, 0.21
# Data received: 0.09, 0.93, 0.19
# Data received: -0.07, 0.90, 0.42
# Data received: 0.25, 1.03, 0.22
# Data received: 0.10, 1.02, 0.19
# Data received: 0.03, 1.13, -0.01
# Data received: -0.04, 0.95, -0.25
# Data received: -0.02, 0.98, -0.28
# Data received: 0.08, 0.98, -0.12
# Data received: -0.02, 1.20, -0.19
# Data received: -0.22, 1.01, 0.04
# Data received: -0.24, 0.94, 0.06
# Data received: -0.07, 1.02, -0.23
# Data received: -0.06, 0.96, 0.17
# Data received: -0.17, 1.06, 0.02
# Data received: -0.30, 1.10, 0.15
# Data received: -0.22, 0.86, 0.31
# Data received: -0.25, 1.05, -0.03
# Data received: 0.10, 0.89, 0.11
# Data received: -0.20, 0.98, 0.10
# Data received: -0.30, 0.94, 0.14
# Data received: -0.47, 0.72, 0.22
# Data received: -0.29, 0.90, 0.06
# Data received: -0.14, 1.10, 0.05
# Data received: -0.37, 1.01, 0.11
# Data received: -0.54, 1.03, 0.20
# Data received: -0.48, 0.87, 0.23
# Data received: -0.20, 0.90, 0.06
# Data received: -0.19, 0.93, 0.00
# Data received: -0.43, 0.93, 0.18
# Data received: -0.33, 0.97, 0.11
# Data received: -0.43, 1.15, 0.24
# Data received: -0.18, 0.88, 0.29
# Data received: -0.31, 0.81, 0.08
# Data received: -0.40, 0.85, 0.22
# Data received: -0.33, 0.85, 0.26
# Data received: -0.37, 0.85, 0.17
# Data received: -0.13, 0.95, 0.13
# Data received: -0.37, 0.95, 0.12
# Data received: -0.32, 0.90, 0.16
# Data received: -0.37, 0.77, 0.31
# Data received: -0.26, 1.02, 0.02
# Data received: -0.19, 0.95, 0.23
# Data received: -0.30, 0.93, 0.16
# Data received: -0.43, 0.99, 0.11
# Data received: -0.49, 1.04, 0.27
# Data received: -0.10, 0.82, 0.13
# Data received: -0.03, 1.17, 0.03
# Data received: -0.37, 0.89, 0.25
# Data received: -0.39, 0.92, 0.20
# Data received: -0.33, 1.16, 0.11
# Data received: -0.00, 0.94, 0.22
# Data received: -0.20, 0.92, 0.28
# Data received: -0.59, 0.85, 0.23
# Data received: -0.46, 0.83, 0.13
# Data received: -0.37, 0.87, 0.30
# Data received: -0.33, 0.93, 0.22
# Data received: -0.21, 1.00, 0.27
# Data received: -0.38, 0.94, 0.16
# Data received: -0.35, 0.85, 0.35
# Data received: -0.33, 0.94, 0.13
# Data received: -0.22, 0.96, 0.25
# Data received: -0.40, 0.91, 0.08
# Data received: -0.56, 0.74, 0.25
# Data received: -0.39, 0.99, 0.05
# Data received: -0.08, 0.97, 0.10
# Data received: -0.35, 1.01, 0.32
# Data received: -0.42, 0.91, 0.12
# Data received: -0.55, 0.83, 0.13
# Data received: -0.17, 0.74, 0.14
# Data received: -0.18, 1.11, 0.17
# Data received: -0.39, 1.14, 0.25
# Data received: -0.48, 0.84, 0.28
# Data received: -0.17, 0.92, 0.17
# Data received: -0.10, 0.94, 0.23
# Data received: -0.35, 1.03, 0.37
# Data received: -0.50, 0.91, 0.13
# Data received: -0.35, 0.90, 0.22
# Data received: -0.15, 0.82, 0.32
# Data received: -0.36, 0.83, 0.13
# Data received: -0.47, 0.96, 0.11
# Data received: -0.45, 0.81, 0.15
# Data received: -0.47, 1.10, 0.01
# Data received: -0.26, 1.03, 0.13
# Data received: -0.36, 1.26, 0.30
# Data received: -0.50, 0.91, 0.13
# Data received: -0.55, 0.77, 0.24
# Data received: -0.29, 1.07, 0.13
# Data received: -0.13, 0.85, 0.37
# Data received: -0.51, 0.93, 0.48
# Data received: -0.60, 0.89, 0.18
# Data received: -0.40, 0.82, 0.17
# Data received: -0.18, 0.79, 0.30
# Data received: -0.50, 0.99, 0.17
# Data received: -0.58, 0.71, 0.31
# Data received: -0.35, 0.86, 0.21
# Data received: -0.14, 1.04, 0.23
# Data received: -0.14, 0.82, 0.41
# Data received: -0.39, 0.90, 0.07
# Data received: -0.53, 0.95, 0.19
# Data received: -0.47, 0.75, 0.19
# Data received: -0.04, 0.98, 0.22
# Data received: -0.16, 1.00, 0.26
# Data received: -0.39, 0.94, 0.32
# Data received: -0.58, 0.75, 0.31
# Data received: -0.50, 0.81, 0.33
# Data received: -0.17, 0.87, 0.31
# Data received: -0.43, 0.84, 0.14
# Data received: -0.49, 0.84, 0.18
# Data received: -0.49, 1.14, 0.12
# Data received: -0.13, 0.75, 0.10
# Data received: -0.38, 1.16, 0.18
# Data received: -0.53, 0.76, 0.37
# Data received: -0.50, 0.83, 0.29
# Data received: -0.21, 0.84, 0.25
# Data received: -0.10, 0.99, 0.27
# Data received: -0.40, 1.01, 0.26
# Data received: -0.52, 1.09, 0.13
# Data received: -0.56, 0.95, 0.20
# Data received: -0.06, 0.85, 0.15
# Data received: -0.39, 0.95, 0.04
# Data received: -0.50, 0.78, 0.22
# Data received: -0.49, 0.90, 0.26
# Data received: -0.52, 0.93, 0.04
# Data received: -0.27, 1.05, 0.41
# Data received: -0.37, 0.96, 0.13
# Data received: -0.36, 0.93, 0.21
# Data received: -0.55, 0.84, 0.24
# Data received: -0.54, 0.85, -0.04
# Data received: -0.05, 0.99, 0.23
# Data received: -0.15, 1.09, 0.43
# Data received: -0.45, 0.90, 0.26
# Data received: -0.35, 0.88, 0.15
# Data received: -0.54, 0.74, 0.20
# Data received: -0.46, 0.89, 0.29
# Data received: -0.23, 0.91, 0.19
# Data received: -0.47, 0.80, 0.32
# Data received: -0.49, 0.87, 0.13
# Data received: -0.43, 0.90, 0.23
# Data received: -0.29, 0.94, 0.26
# Data received: -0.31, 0.77, 0.44
# Data received: -0.53, 0.83, 0.28
# Data received: -0.49, 0.76, 0.33
# Data received: -0.35, 0.79, 0.22
# Data received: 0.04, 0.95, 0.29
# Data received: -0.36, 0.64, 0.42
# Data received: -0.45, 0.91, 0.25
# Data received: -0.59, 0.75, 0.33
# Data received: -0.06, 0.96, 0.30
# Data received: 0.02, 0.83, 0.32
# Data received: -0.64, 0.78, 0.51
# Data received: -0.63, 0.72, 0.19
# Data received: -0.46, 0.76, 0.30
# Data received: -0.28, 0.74, 0.47
# Data received: -0.47, 0.77, 0.25
# Data received: -0.48, 0.81, 0.29
# Data received: -0.57, 0.70, 0.33
# Data received: -0.24, 1.15, 0.34
# Data received: -0.21, 0.89, 0.40
# Data received: -0.41, 0.77, 0.35
# Data received: -0.59, 0.85, 0.18
# Data received: -0.65, 0.91, 0.38
# Data received: -0.13, 1.08, 0.53
# Data received: -0.20, 0.74, 0.32
# Data received: -0.63, 0.44, 0.31
# Data received: -0.63, 0.78, 0.13
# Data received: -0.77, 0.58, 0.10
# Data received: -0.54, 0.43, 0.50
# Data received: -0.15, 0.95, -0.02
# Data received: -0.28, 1.04, 0.17
# Data received: -0.56, 0.79, 0.28
# Data received: -0.16, 0.83, 0.29
# Data received: -0.11, 0.36, 0.79
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.05, 1.02
# Data received: -0.02, -0.06, 1.02
# Data received: -0.01, -0.03, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: 0.05, -0.02, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.02, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# ...
# Data received: -0.21, 0.81, 1.50
# Data received: -0.16, 0.07, 1.02
# Data received: -0.30, 0.29, 1.79
# Data received: 0.31, 0.85, 0.95
# Data received: -1.17, 0.28, -0.06
# Data received: 0.48, 3.47, 4.00
# Data received: -1.06, 0.41, 0.55
# Data received: -0.96, -2.10, 1.69
# Data received: -0.03, -0.62, 1.38
# Data received: -0.85, -2.34, 1.25
# Data received: -0.87, -1.99, 1.15
# Data received: -0.89, -0.58, 3.76
# Data received: -0.09, 0.55, 1.69
# Data received: 0.05, 0.44, 1.93
# Data received: 0.61, -0.65, -0.10
# Data received: -0.01, 0.02, 1.24
# Data received: 0.27, 0.07, 0.81
# Data received: 0.60, -0.67, -0.96
# Data received: 0.10, -0.26, 0.27
# Data received: 0.66, -0.72, -0.20
# Data received: 0.51, -0.83, -0.10
# Data received: -0.39, -0.12, 0.67
# Data received: -0.02, 0.82, 2.40
# Data received: 0.56, -0.01, 0.11
# Data received: -0.36, -0.83, 0.59
# Data received: 0.24, -0.51, 0.75
# Data received: 0.10, -0.42, 0.55
# Data received: -0.72, 0.55, 1.91
# Data received: 0.17, 0.39, 1.17
# Data received: -0.30, 0.84, 2.05
# Data received: 0.51, -0.53, 0.04
# Data received: 0.06, 0.75, 1.17
# Data received: 0.32, -0.11, 0.67
# Data received: -0.35, 0.83, 0.95
# Data received: -1.08, -0.02, 1.44
# Data received: -0.67, -0.28, 0.05
# Data received: -0.28, 1.86, 2.01
# Data received: -0.70, -1.07, 1.08
# Data received: -1.29, -0.24, 1.25
# Data received: -0.35, 0.21, 2.65
# Data received: 0.27, -0.91, 0.02
# Data received: 0.42, 0.53, 0.09
# Data received: -0.68, 0.15, 2.57
# Data received: -0.71, -0.30, 0.81
# Data received: 0.91, -0.54, 0.14
# Data received: 0.47, 0.30, 1.02
# Data received: -0.12, 0.52, 1.24
# Data received: -0.38, 0.35, 1.15
# Data received: 0.14, -0.13, 0.57
# Data received: 0.17, -0.44, 0.39
# Data received: 0.45, -0.65, 0.32
# Data received: 0.28, 0.06, 0.76
# Data received: -0.29, 0.47, 1.38
# Data received: 0.02, 0.33, 0.99
# Data received: -0.03, 0.06, 0.91
# Data received: 0.84, 0.01, -0.11
# Data received: -0.20, -0.09, 1.02
# Data received: 0.48, -0.04, 0.40
# Data received: 0.53, -0.42, 0.42
# Data received: -0.43, 0.82, 1.39
# Data received: -0.12, 0.46, 0.95
# Data received: 0.01, 0.26, 1.09
# Data received: -0.41, 0.70, 1.49
# Data received: -0.03, 0.52, 0.88
# Data received: -0.19, 0.56, 1.28
# Data received: 0.25, -0.47, 0.22
# Data received: -0.14, 0.15, 1.37
# Data received: -0.08, 0.11, 1.30
# Data received: 0.42, -0.32, -0.08
# Data received: 0.48, -0.47, 0.16
# Data received: 0.30, -0.37, 0.69
# Data received: 0.25, 0.14, 0.81
# Data received: 0.18, 0.32, 0.97
# Data received: 0.18, -0.47, 0.64
# Data received: 0.49, -0.10, 0.50
# Data received: 0.07, 0.52, 1.53
# Data received: 0.39, -0.92, 0.03
# Data received: -1.06, 0.26, 2.89
# Data received: -0.14, 0.33, 1.10
# Data received: -0.07, -0.19, 0.72
# Data received: 0.43, -0.31, 0.02
# Data received: 0.18, -0.21, 0.37
# Data received: 0.61, 0.12, 0.89
# Data received: 0.53, -0.68, 0.12
# Data received: 0.21, 0.10, 0.96
# Data received: 0.43, 0.04, 0.66
# Data received: 0.20, 0.00, 0.80
# Data received: 0.07, 0.08, 1.25
# Data received: 0.20, 0.19, 0.97
# Data received: 0.50, 0.63, 1.21
# Data received: 0.44, 0.12, 0.86
# Data received: 0.45, 0.21, 0.89
# Data received: 0.77, 0.26, 0.51
# Data received: 0.25, 0.71, 1.43
# Data received: 0.35, 0.17, 0.95
# Data received: 0.73, 0.59, 0.96
# Data received: -0.06, -0.12, 1.03
# Data received: -0.13, 0.06, 0.90
# Data received: 0.37, 0.12, 1.19
# Data received: 0.13, 0.17, 1.18
# Data received: 0.10, -0.42, 0.68
# Data received: 0.21, 0.11, 0.77
# Data received: -0.47, 0.01, 1.06
# Data received: -0.28, -0.03, 1.43
# Data received: 0.78, 0.01, 0.28
# Data received: 1.06, 0.18, -0.26
# Data received: 0.77, 0.08, 0.34
# Data received: -0.02, 0.23, 1.72
# Data received: 0.98, 0.11, -2.59
# Data received: -0.64, 0.26, 0.56
# Data received: -0.27, -0.15, 0.99
# Data received: 0.09, 0.19, -0.02
# Data received: 0.40, 0.00, 0.20
# Data received: 0.06, 1.09, 2.89
# Data received: 0.59, -0.62, -0.01
# Data received: -0.15, -1.27, 0.36
# Data received: 0.39, 0.53, 1.14
# Data received: -0.18, -0.56, 0.96
# Data received: -0.56, -0.78, 1.50
# Data received: 0.53, -0.44, 0.99
# Data received: 0.48, 0.52, 1.00
# Data received: 0.30, -0.34, 0.80
# Data received: 0.05, -0.62, 0.88
# Data received: 0.32, 0.10, 0.59
# Data received: 0.41, 0.14, 0.67
# Data received: 0.48, 1.13, 1.32
# Data received: 0.35, 0.88, 2.21
# Data received: 0.40, -0.42, -0.49
# Data received: -0.25, -0.83, 1.17
# Data received: -0.13, -1.21, -2.03
# Data received: -0.09, 0.76, 0.99
# Data received: -0.12, -0.29, 0.28
# Data received: 0.06, -0.17, 0.57
# Data received: -0.08, 0.25, 1.09
# Data received: -0.56, 0.53, 1.48
# Data received: -0.36, 0.43, 1.75
# Data received: 0.88, 0.59, 0.00
# Data received: 0.19, -0.35, 0.56
# Data received: -0.41, 0.85, 1.20
# Data received: -0.29, -0.10, 1.12
# Data received: -0.12, -0.41, 0.60
# Data received: 0.93, -0.28, -0.45
# Data received: 0.55, -0.15, 0.98
# Data received: -0.51, -0.73, 0.57
# Data received: -0.31, -0.62, 0.60
# Data received: 0.75, 0.59, 0.84
# Data received: -0.02, 0.42, 1.32
# Data received: -0.28, -0.33, 1.17
# Data received: 0.52, 0.29, -0.57
# Data received: 0.46, -0.94, -1.12
# Data received: 0.31, -0.49, -0.03
# Data received: 0.22, 1.76, 0.97
# Data received: -0.72, 0.66, 1.69
# Data received: -0.21, -0.31, 0.68
# Data received: -0.14, -0.02, 0.89
# Data received: -0.90, -0.07, 1.74
# Data received: 0.27, -0.65, -0.33
# Data received: 0.35, -0.17, 0.34
# Data received: -0.15, 1.01, 1.22
# Data received: 0.50, 0.45, 0.26
# Data received: -0.16, -0.22, 0.50
# Data received: -0.43, -1.17, 1.65
# Data received: -0.78, 0.04, 0.12
# Data received: -2.85, -2.22, 1.57
# Data received: 1.10, 1.03, 0.89
# Data received: -1.96, -0.87, 1.09
# Data received: 0.72, 0.29, 0.24
# Data received: -1.59, -1.52, 0.50
# Data received: -0.81, -0.96, -0.94
# Data received: 1.39, 0.20, -1.36
# Data received: 0.01, -0.29, 0.99
# Data received: -0.00, -0.03, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.03, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.03, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.03, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.03, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.00, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.03, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.01
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data received: -0.01, -0.04, 1.02
# Data collection stopped.
# Serial port closed.
#             timestamp    x     y     z
# 0 2024-07-24 14:07:12 -0.0 -0.03  1.01
# 1 2024-07-24 14:07:13 -0.0 -0.03  1.01
# 2 2024-07-24 14:07:14 -0.0 -0.03  1.01
# 3 2024-07-24 14:07:15 -0.0 -0.03  1.01
# 4 2024-07-24 14:07:16 -0.0 -0.03  1.01
